# %% [markdown]
# ## Test Notebook
# This is a super quick test to make sure that cellpose is installed corrrectly and that the GPU is being detected.
#
# Run the two cells, and you should get "Model is using GPU: True"
#
# edited May 6, 2025

# %%
import cellpose
# Out:
# Welcome to CellposeSAM, cellpose v4.0.1! The neural network component of
# CPSAM is much larger than in previous versions and CPU excution is slow.
# We encourage users to use GPU/MPS if available.

# %%
from cellpose import models

# Create model without specifying GPU so it auto-detects
model = models.CellposeModel(gpu=True)

# Check if model is actually using GPU
print("Model is using GPU:", model.gpu)
# Out:
# 100%|███████████████████████████████████████| 1.15G/1.15G [00:02<00:00, 423MB/s]
# Model is using GPU: True
